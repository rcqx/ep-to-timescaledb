# %%
import pandas as pd
import matplotlib.pyplot as plt
from rdflib import RDF, RDFS, OWL, Namespace, Graph
import psycopg2
# %matplotlib inline

# %%
g = Graph()

# %%
g.parse("bot_office.ttl", format="ttl")
# Out:
# <Graph identifier=Nae5c8377c191481da46751b74a3178f6 (<class 'rdflib.graph.Graph'>)>

# %%
res = g.query("""
SELECT ?s WHERE {
    # ?s a bot:Space .
    }
""")
for row in res:
    print(row)
# Out:
# (rdflib.term.URIRef('http://example.com/5ZoneOffice#office_C'),)
# (rdflib.term.URIRef('http://example.com/5ZoneOffice#office_E'),)
# (rdflib.term.URIRef('http://example.com/5ZoneOffice#office_N'),)
# (rdflib.term.URIRef('http://example.com/5ZoneOffice#office_S'),)
# (rdflib.term.URIRef('http://example.com/5ZoneOffice#office_W'),)

# %%
# Fetch Sensors in zones
for zone, sensor in g.query("""
    SELECT ?zone ?sensor WHERE {
        # ?zone a bot:Zone .
        # ?zone bot:hasElement ?sensor .
        # ?sensor a bot:Element .
    }
"""):
    print(zone, sensor)
# Out:
# http://example.com/5ZoneOffice#ZONE_C http://example.com/5ZoneOffice#TS_Core
# http://example.com/5ZoneOffice#ZONE_E http://example.com/5ZoneOffice#TS_East
# http://example.com/5ZoneOffice#ZONE_N http://example.com/5ZoneOffice#TS_North
# http://example.com/5ZoneOffice#ZONE_S http://example.com/5ZoneOffice#TS_South
# http://example.com/5ZoneOffice#ZONE_W http://example.com/5ZoneOffice#TS_West

# %%
# Define method
def sparql_to_df(g,q):
    res = g.query(q)
    df = pd.DataFrame.from_records(list(res))
    df = df.applymap(str)
    df.drop_duplicates(inplace=True)
    return df

# %%
def get_sim(zoneids):
    with psycopg2.connect("host=timescaledb port=5432 user=postgres password=multipass") as conn:
        sql = "SELECT time, value, zoneid FROM data WHERE zoneid = ANY(%s)"
        df = pd.read_sql(sql, conn, params=(zoneids,))
        df = df.pivot(columns="zoneid", values="value", index="time")
        df = df.resample('15T').mean()
        #df.columns = names
        return df

# %%
# Fetch sensors in zones with associated uuids
q = """
    SELECT ?zone ?sensor ?tsid WHERE {
        # ?zone a bot:Zone .
        # ?zone bot:hasElement ?sensor .
        # ?sensor a bot:Element ;
                bldg:timeseries/bldg:hasTimeseriesId ?tsid .
    }
"""
md = sparql_to_df(g,q) 
md
# Out:
#                                        0  \
# 0  http://example.com/5ZoneOffice#ZONE_C
# 2  http://example.com/5ZoneOffice#ZONE_E
# 4  http://example.com/5ZoneOffice#ZONE_N
# 6  http://example.com/5ZoneOffice#ZONE_S
# 8  http://example.com/5ZoneOffice#ZONE_W
#
#                                          1             2
# 0   http://example.com/5ZoneOffice#TS_Core   CoreZone-id
# 2   http://example.com/5ZoneOffice#TS_East   EastZone-id
# 4  http://example.com/5ZoneOffice#TS_North  NorthZone-id
# 6  http://example.com/5ZoneOffice#TS_South  SouthZone-id
# 8   http://example.com/5ZoneOffice#TS_West   WestZone-id

# %%
# Retrieve all zones values 
for (zone, sensor, zoneid) in md.values:
    core = get_sim(["CoreZone-id"])
core.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
for (zone, sensor, zoneid) in md.values:
    west = get_sim(["WestZone-id"])
west.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
for (zone, sensor, zoneid) in md.values:
    east = get_sim(["EastZone-id"])
east.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
for (zone, sensor, zoneid) in md.values:
    north = get_sim(["NorthZone-id"])
north.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
for (zone, sensor, zoneid) in md.values:
    south = get_sim(["SouthZone-id"])
south.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
zones=[north,south,east,west,core]
zones
# Out:
# [zoneid                     NorthZone-id
#  time
#  2021-06-29 00:30:00+00:00     24.393227
#  2021-06-29 00:45:00+00:00     24.291062
#  2021-06-29 01:00:00+00:00     24.195435
#  2021-06-29 01:15:00+00:00     24.106873
#  2021-06-29 01:30:00+00:00     24.024516
#  ...                                 ...
#  2021-06-29 23:00:00+00:00     25.234671
#  2021-06-29 23:15:00+00:00     25.063499
#  2021-06-29 23:30:00+00:00     24.895444
#  2021-06-29 23:45:00+00:00     24.748717
#  2021-06-30 00:00:00+00:00     24.619916
#
#  [95 rows x 1 columns],
#  zoneid                     SouthZone-id
#  time
#  2021-06-29 00:30:00+00:00     24.374300
#  2021-06-29 00:45:00+00:00     24.276163
#  2021-06-29 01:00:00+00:00     24.184060
#  2021-06-29 01:15:00+00:00     24.098624
#  2021-06-29 01:30:00+00:00     24.019041
#  ...                                 ...
#  2021-06-29 23:00:00+00:00     25.177049
#  2021-06-29 23:15:00+00:00     25.014023
#  2021-06-29 23:30:00+00:00     24.853622
#  2021-06-29 23:45:00+00:00     24.713861
#  2021-06-30 00:00:00+00:00     24.591132
#
#  [95 rows x 1 columns],
#  zoneid                     EastZone-id
#  time
#  2021-06-29 00:30:00+00:00    24.423890
#  2021-06-29 00:45:00+00:00    24.322272
#  2021-06-29 01:00:00+00:00    24.226795
#  2021-06-29 01:15:00+00:00    24.137956
#  2021-06-29 01:30:00+00:00    24.054937
#  ...                                ...
#  2021-06-29 23:00:00+00:00    25.238133
#  2021-06-29 23:15:00+00:00    25.073429
#  2021-06-29 23:30:00+00:00    24.912812
#  2021-06-29 23:45:00+00:00    24.772415
#  2021-06-30 00:00:00+00:00    24.647509
#
#  [95 rows x 1 columns],
#  zoneid                     WestZone-id
#  time
#  2021-06-29 00:30:00+00:00    24.606819
#  2021-06-29 00:45:00+00:00    24.481192
#  2021-06-29 01:00:00+00:00    24.364857
#  2021-06-29 01:15:00+00:00    24.257925
#  2021-06-29 01:30:00+00:00    24.159199
#  ...                                ...
#  2021-06-29 23:00:00+00:00    25.660628
#  2021-06-29 23:15:00+00:00    25.443518
#  2021-06-29 23:30:00+00:00    25.235040
#  2021-06-29 23:45:00+00:00    25.051930
#  2021-06-30 00:00:00+00:00    24.889993
#
#  [95 rows x 1 columns],
#  zoneid                     CoreZone-id
#  time
#  2021-06-29 00:30:00+00:00    24.433076
#  2021-06-29 00:45:00+00:00    24.345479
#  2021-06-29 01:00:00+00:00    24.263576
#  2021-06-29 01:15:00+00:00    24.187486
#  2021-06-29 01:30:00+00:00    24.116678
#  ...                                ...
#  2021-06-29 23:00:00+00:00    25.194475
#  2021-06-29 23:15:00+00:00    25.037823
#  2021-06-29 23:30:00+00:00    24.881174
#  2021-06-29 23:45:00+00:00    24.745060
#  2021-06-30 00:00:00+00:00    24.629365
#
#  [95 rows x 1 columns]]
